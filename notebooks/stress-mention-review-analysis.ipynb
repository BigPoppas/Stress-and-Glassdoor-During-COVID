# %% [markdown]
# # Analysis of Reviews Containing Identified Stress Mentions
#
# **Purpose**: This notebook delves into the reviews that have been flagged for containing one or more of the stress mentions identified in the `medical-entity-analysis.ipynb` notebook. The aim is to understand the context and prevalence of these mentions within the broader dataset.
#
# **Description**:
# - **Filtering Process**: The initial step involves filtering the reviews to retain only those that match the identified stress mentions.
# - **Observational Analysis**: A basic observational analysis is conducted on the filtered dataset to understand patterns, frequencies, and other key metrics.
# - **Stress Score Extraction**: Adhering to the methodology described in the literature, a stress score will be computed for each company based on the propotion of tis posts related to stress. This score provides a quantitative measure of the stress level associated with each company.
# - **Comparative Analysis**: The notebook also compares key statistics between the entire dataset and the filtered subset. This comparison provides insights into how the presence of stress mentions affects the overall tone and content of reviews.

# %%
import os
import numpy as np
import pandas as pd

import plotly.graph_objects as go

# %%
# Set the Pandas display option to show the entire content of each cell without truncation
pd.set_option('display.max_colwidth', None)

# %%
GREEN = "\033[92m"  # ANSI escape code for green text color
ENDC = "\033[0m"    # ANSI escape code to reset text color to default

# %% [markdown]
# ## 1. Data Loading

# %%
# Specify the path to the folder containing the data (relative)
path = os.path.join("..", "..", "..", "Data")

# File containing the stress entities
txt_fpath = os.path.join(path, "stress_entities.txt")

# File containing glassdoor's reviews
reviews_fpath = os.path.join(path, "reviews.csv")

# File containing glassdoor companies
companies_fpath = os.path.join(path, "companies.json")

# %%
# Load the TXT file into a Python List object
stress_entities = []

with open(txt_fpath, "r") as file:
    text = file.read()

    text = text.replace("'", "")
    text = text.replace("[", "").replace("]", "")
    
    stress_entities = text.split(",")

# %%
# Load the reviews CSV file into a Pandas DataFrame object
reviews = pd.read_csv(reviews_fpath)
reviews.dropna(subset="summary", inplace=True)

# %%
# Load the companies CSV file into a Pandas DataFrame object
companies = pd.read_json(companies_fpath)

# %% [markdown]
# ## 2. Preview of Stress Mentioned Reviews
#
# The extracted list of stress entities will now be used to sample some reviews that contain the related mentions

# %%
def find_reviews_with_pattern(pattern, case=False, n=10):
    # Filter reviews to find rows where the summary collumn contains the desired pattern
    matching_reviews = reviews[reviews["summary"].str.contains(pattern, case=case)]
    matching_reviews = matching_reviews["summary"]
    matching_reviews.reset_index(drop=True, inplace=True)
    
    count = matching_reviews.shape[0]
    matching_reviews = matching_reviews.head(n)

    return (matching_reviews, count)

# %%
for entity in stress_entities:
    matching_reviews, count = find_reviews_with_pattern(entity)

    print(f"Total matching reviews for {GREEN}{entity}{ENDC}: {count}")
    print(matching_reviews, "\n")
# Out:
# Total matching reviews for stress: 25489
# 0                                                                                      Stressful & Frustrating
# 1                                                                                                    Stressful
# 2                                                                                                   Stressfull
# 3                                                                  My experience consists of being stressed...
# 4    Fun people, chaotic day-to-day, no work-life balance, poor information sharing, high stress, no training.
# 5                                                                                  Stressful at times but fine
# 6                                                                      Disorganized, stressful and incompetent
# 7                                                                                         very stress full job
# 8                                                                    High stress for little base salary reward
# 9                                                                                Stressful only if you make it
# Name: summary, dtype: object
#
# Total matching reviews for  high stress: 1291
# 0    Fun people, chaotic day-to-day, no work-life balance, poor information sharing, high stress, no training.
# 1                                                                                         Good but high stress
# 2                                                                 Low pay, high stress, little appreciation...
# 3                                                                         Great Pay, NO training,  high stress
# 4                                                             Good money, high stress & poor work life balance
# 5                                               Great Growth Potential; High Stress, High Pressure Environment
# 6                                                                                     Long hours, high stress.
# 7                                                                                     Good job but high stress
# 8                                          Good company, good people, but often under pressure and high stress
# 9                                                                           Fast Paced, High Stress Enviroment
# Name: summary, dtype: object
#
# Total matching reviews for  low stress: 339
# 0                                                                     Emerson has a great work environment, with low stress.
# 1                                                                                   Great Place for Stability and Low Stress
# 2                                                                                                       Easy Job, Low Stress
# 3                                                                                        Comfortable, low stress, boring job
# 4    JHU APL is a great place to work if you value job flexibility, low stress atmosphere, reasonable pay and job stability.
# 5                                                                                                      Easy pace; low stress
# 6                                                  Casual and relaxed position with low pay but low stress and nice benefits
# 7                                                                                               Old Defense Woes, Low Stress
# 8                                                                                         Fexible and low stress environment
# 9                                                                                  NOT a low stress environment by any means
# Name: summary, dtype: object
#
# Total matching reviews for  burnout: 1022
# 0                    Cool brand but a huge burnout factor.
# 1              Good career building block but high burnout
# 2                                       Guaranteed Burnout
# 3                 Good Role But A Potential Burnout Occurs
# 4                                         Too much burnout
# 5                                             High Burnout
# 6                             Rampant and unending burnout
# 7    Growth Potential, But eventually will lead to burnout
# 8            Alright environment, but you burnout quickly.
# 9                 Great company, but can cause burnout too
# Name: summary, dtype: object
#
# Total matching reviews for  anxiety: 245
# 0                                 Mid, really depends on your team (can be stressful / anxiety inducing). Pay is good
# 1                                                                                    Not worth the stress and anxiety
# 2                                                                                                XPO  gave me anxiety
# 3                                                                     It's a good job unless you have anxiety like me
# 4                                                      Good place to work, but a lot of anxiety from potential buyout
# 5                                                       People enter with enthusiasm but leave with  RAGE and ANXIETY
# 6                                       Whirlpool assembly great job unfortunately impossible for me with my anxiety.
# 7    If you're lucky and have the right support Amazon could change your life. It could also cause you major anxiety.
# 8                                          Incredible role with growth opportunities and a big scoop of acute anxiety
# 9                                                If you don't have anxiety now, you will once you start working here.
# Name: summary, dtype: object
#
# Total matching reviews for  depression: 133
# 0                                                             They drive you to depression
# 1                         HAHA work here if you want depression or to be sexually harassed
# 2            Terrible experience still suffer from depression because of how I was treated
# 3                      Poor middle management understanding of depression in the workplace
# 4                                                               Hubspot gave me depression
# 5                                                                     Perpetual depression
# 6                                                       Not good for those with Depression
# 7                                                        Almost pushed me to depression...
# 8    Great co-workers, but crappy job and managers that can lead to depression and anxiety
# 9                                              This place literally put me in a depression
# Name: summary, dtype: object
#
# Total matching reviews for  headache: 831
# 0                           Excellent pay, lots of headaches
# 1    Work/life balance for little pay not worth the headache
# 2                               It is not worth the headache
# 3             A Great Opportunity But Not Worth The Headache
# 4                                     Not worth the headache
# 5          Great start and great money, great headaches too!
# 6                             This place gives me a headache
# 7     Elite university with the usual bureaucratic headaches
# 8                          Not worth the headache or low pay
# 9        Nothing challenging and Office Politics is headache
# Name: summary, dtype: object
#
# Total matching reviews for  headaches: 262
# 0                            Excellent pay, lots of headaches
# 1           Great start and great money, great headaches too!
# 2      Elite university with the usual bureaucratic headaches
# 3                                 Totally worth the headaches
# 4                                Quick money, quick headaches
# 5                           Endless shrimp, endless headaches
# 6           Here's some headaches to go with your deliveries!
# 7    A lot of headaches and responsibility for very low wages
# 8                        Slow pay, fast calls, much headaches
# 9                             Great Perks, for the Headaches!
# Name: summary, dtype: object
#
# Total matching reviews for  pain: 5828
# 0    great company original going through transition pains and loosing original atmosphere
# 1                                            Great company experiencing some growing pains
# 2                    Small company transitioning to large business with some growing pains
# 3            Great employer, good opportunities, despite some understandable growing pains
# 4                                                               A slow and painful decline
# 5                                                                            Growing Pains
# 6                       Is it just growing pains or are mistakes being made? Hard to tell.
# 7                                                Big Company Pains with Small Company Feel
# 8                                                     Start-up  =  Growing pains.. Period!
# 9                                          Lots of upside; With growth comes growing pains
# Name: summary, dtype: object
#
# Total matching reviews for  pains: 4264
# 0    great company original going through transition pains and loosing original atmosphere
# 1                                            Great company experiencing some growing pains
# 2                    Small company transitioning to large business with some growing pains
# 3            Great employer, good opportunities, despite some understandable growing pains
# 4                                                                            Growing Pains
# 5                       Is it just growing pains or are mistakes being made? Hard to tell.
# 6                                                Big Company Pains with Small Company Feel
# 7                                                     Start-up  =  Growing pains.. Period!
# 8                                          Lots of upside; With growth comes growing pains
# 9                                               Great company, going through growing pains
# Name: summary, dtype: object
#
# Total matching reviews for  low morale: 642
# 0                        Return To Office Causing Mass Chaos and Low Morale
# 1                                                Bad culture and low morale
# 2                                            Talented employees, low morale
# 3                                           Toxic leadership and low morale
# 4                                       Pretty low morale and high turnover
# 5                                        Poor management lead to low morale
# 6                           Sinking Ship of Low Morale, Clueless Leadership
# 7                                             Unclear future and low morale
# 8                                            Great benefits, but low morale
# 9    Good project, Low Morale, Everyone has a 'it is what it is' philosophy
# Name: summary, dtype: object
#
# Total matching reviews for  poor morale: 139
# 0                  Solid, busy work but poor morale and middle management.
# 1                               Lack of labor distribution and poor morale
# 2    Well managed for performance but very poor morale and upward mobility
# 3                                            Union busting and poor morale
# 4               good financial results hide poor morale, but for how long?
# 5      Too many internal silos for good cross-communication.  Poor morale.
# 6                                               Nice teams but poor morale
# 7                                     Poor management leads to poor morale
# 8              OK Place to Work, poor morale, and major layoffs this year.
# 9                                 Great teams and benefits but poor morale
# Name: summary, dtype: object
#
# Total matching reviews for  pressure: 7950
# 0                                                                                                   No Pressure
# 1    Terrible place to work: instability, lack of ethic, transparency and high pressure for short term results.
# 2                                                                                  Micromanagement and pressure
# 3                                                                             No pressure, positive environment
# 4                                                                     Good work Culture and no pressure at work
# 5                                                                                                 High pressure
# 6            Working to maximum optimised efficiency. Very high pressure and high workload with little support.
# 7                                                        Get Stress, Blood pressure and other diseases for free
# 8                                                                            High pressure no work life balance
# 9                                                                                        Too much work pressure
# Name: summary, dtype: object
#
# Total matching reviews for  dysfunction: 1522
# 0                                   Like a happy, but somewhat dysfunctional family
# 1                                      Interesting work, dysfunctional organization
# 2    Great Opportunities but rife with needlessly dysfunctional processes and comms
# 3                                                                Very dysfunctional
# 4               Utterly Despicable Company, Dysfunctional, Chaotic work environment
# 5                                                  Poorly managed and dysfunctional
# 6                        The most dysfunctional organization I've ever encountered.
# 7                                   Never seen such dysfunction in an organization!
# 8                                                Completely dysfunctional in Canada
# 9                 Good people, but culture of dysfunction and decision by committee
# Name: summary, dtype: object
#
# Total matching reviews for  bullying: 1193
# 0                   Passive Aggressive attacks & Bullying culture is encouraged
# 1                               Flexible but dated technology and bullying rife
# 2                                                           they allow bullying
# 3                      HR encourages bullying & discrimination in the workplace
# 4                                        Toxic leadership and systemic bullying
# 5                                         Horrendous experience due to bullying
# 6                                If you like bullying this is the place for you
# 7    Unsafe for patients, bullying management, patient safety is not a priority
# 8                                     Emotion Distress and Guilt Bullying in HR
# 9                                          Widespread bullying and incompetence
# Name: summary, dtype: object
#
# Total matching reviews for  overworked: 3551
# 0                          underpaid, overworked, unappreciated
# 1                          Amazing company, slightly overworked
# 2    If you dont mind being overworked its a good place to work
# 3     Good Company but after buy-out Overworked and Overwhelmed
# 4                        Underpaid, understaffed and overworked
# 5                                          Underpaid overworked
# 6          At best you'll be constantly stressed and overworked
# 7                     You will grow, and you will be overworked
# 8                                     Under paid and overworked
# 9                                      Stressful and Overworked
# Name: summary, dtype: object
#
# Total matching reviews for  heavy workload: 613
# 0       Ok benefits, no compensation for heavy workload
# 1             Learning Opportunities and heavy workload
# 2                            Low income, Heavy workload
# 3                       Lecturers have a heavy workload
# 4                          Good Company, heavy workload
# 5                  Good pay, fine hours, heavy workload
# 6                            Higher Pay, Heavy Workload
# 7    Flexible schedule, but comes with a heavy workload
# 8                      Smart people, heavy workload....
# 9              Very good salary but also heavy workload
# Name: summary, dtype: object

# %% [markdown]
# ## 3. Filtering Reviews
#
# Now we will generate a new DataFrame that retains only the rows which their review contains at least one of the identified stress mentions.

# %%
mask = reviews["summary"].str.contains("|".join(stress_entities), case=False)

# %%
filtered_reviews = reviews[mask].copy()
filtered_reviews.reset_index(drop=True, inplace=True)

# %%
filtered_reviews["summary"].sample(10)
# Out:
# 8976     Starts off very fun and slowly becomes more stressful. While not commission, pressure is there to meet number targets.
# 319                                                                                                           Far too stressful
# 11501                                                                                                                 Stressing
# 27302                                                                                                                 Stressful
# 41462                                                                                             Best place if you love stress
# 3194                                                                   Good paying job could be very stressful most of the time
# 20415                                                                                                          Growing pains...
# 18352                                                                                                            Too stressfull
# 5639                                                                                                      Head Cashier Headache
# 2031                                                                                                          It's so stressful
# Name: summary, dtype: object

# %%
# How many records are we left with?
filtered_reviews.shape[0]
# Out:
# 48631

# %% [markdown]
# Let us also add a new boolean column to the existing DataFrame indicating whether a stress metnion is present in the summary column

# %%
reviews["has_stress"] = mask

# %%
reviews[reviews["has_stress"] == 1][["has_stress", "summary"]].sample(5)
# Out:
#          has_stress                                                  summary
# 5656083        True             Nepotism, precarious and stressful managemnt
# 5647315        True  Difficult work environment, smart people, high pressure
# 5698499        True                                High turnover and burnout
# 8104845        True             Great place to work, long hours, some stress
# 8647502        True                     good if you like high pressure sales

# %% [markdown]
# ## 4. Stress Score Extraction

# %% [markdown]
# ### 4.1. Associating Stress Types with Companies
# Following the literture's methodology, we will compute the stress score for each company based on the proportion of its posts related to stress. This involves calculating the average review rating and stress score for each company, followed by z-scoring these values for comparability.
#
# Since we want to find how COVID-19 affected the reviews and the overall stress of the employees we will compute the rating and stress before and after covid.

# %%
# Cut-off point of COVID-19
covid_start_date = "2019-12-25"

# %%
reviews["reviewDateTime"] = pd.to_datetime(reviews["reviewDateTime"])

# %%
# Acquire the reviews submited before COVID-19 
reviews_pre_covid = reviews[reviews["reviewDateTime"] < covid_start_date]

# Acquire the reviews submited during COVID-19
reviews_during_covid = reviews[reviews["reviewDateTime"] >= covid_start_date]

# %%
def compute_average_rating_per_company(df):
    # Group by 'company_id' and calculate mean of 'ratingOverall'
    result = df[["ratingOverall", "company_id"]].groupby(by="company_id").mean().reset_index()
    result.columns = ["company_id", "average_rating"]

    # Compute z-score for rating
    result["zrating"] = (result["average_rating"] - result["average_rating"].mean()) / result["average_rating"].std()
    return result

# %%
def compute_stress_score_per_company(df):
    # Reviews per company that had stress mentions
    true_counts = df[["company_id", "has_stress"]].groupby(by="company_id").sum()
    
    # Total number of reviews per company
    total_counts = df[["company_id", "has_stress"]].groupby(by="company_id").count()

    # Compute their ratio / stress score
    result = true_counts / total_counts

    result.reset_index(inplace=True)
    result.columns = ["company_id", "stress"]

    # Drop companies with 0 stress
    result = result[result["stress"] != 0]
    
    # Compute z-score for stress
    result["zstress"] = (result["stress"] - result["stress"].mean()) / result["stress"].std()

    return result

# %%
avg_rating_pre_covid = compute_average_rating_per_company(reviews_pre_covid)
stress_pre_covid = compute_stress_score_per_company(reviews_pre_covid)

results_pre_covid = pd.merge(left=avg_rating_pre_covid, right=stress_pre_covid, on="company_id")
results_pre_covid = pd.merge(left=companies, right=results_pre_covid, left_on="_id", right_on="company_id")

del results_pre_covid["_id"]

# %%
avg_rating_during_covid = compute_average_rating_per_company(reviews_during_covid)
stress_during_covid = compute_stress_score_per_company(reviews_during_covid)

results_during_covid = pd.merge(left=avg_rating_during_covid, right=stress_during_covid, on="company_id")
results_during_covid = pd.merge(left=companies, right=results_during_covid, left_on="_id", right_on="company_id")

del results_during_covid["_id"]

# %%
def plot_quadrants(df, title):
    # Define colors and quadrant names
    quadrants = {
        "Q1": {"name": "Positive Stress", "color": "orange", "position": (3, 3)},  # Top-right quadrant
        "Q2": {"name": "Negative Stress", "color": "red", "position": (-3, 3)},   # Top-left quadrant
        "Q3": {"name": "Passive", "color": "black", "position": (-3, -3)},        # Bottom-left quadrant
        "Q4": {"name": "Low Stress", "color": "green", "position": (3, -3)}       # Bottom-right quadrant
    }
    
    # Determine the quadrant for each point
    df["quadrant"] = df.apply(lambda row: "Q1" if row["zrating"] >= 0 and row["zstress"] >= 0 else 
                              ("Q2" if row["zrating"] < 0 and row["zstress"] >= 0 else 
                              ("Q3" if row["zrating"] < 0 and row["zstress"] < 0 else "Q4")), axis=1)
    
    # Create the base figure
    fig = go.Figure()
    
    # Add scatter points for each quadrant
    for quad, details in quadrants.items():
        df_quad = df[df["quadrant"] == quad]
        fig.add_trace(go.Scatter(x=df_quad["zrating"], y=df_quad["zstress"], 
                                 mode="markers", 
                                 marker=dict(color=details["color"]),
                                 name=details["name"], 
                                 hovertext=df_quad["company name"]))
        
        # Add annotation (text) to indicate the number of companies in the quadrant
        fig.add_annotation(
            text=str(len(df_quad)),
            x=details["position"][0], 
            y=details["position"][1],
            showarrow=False,
            font=dict(
                size=15,
                color=details["color"]
            ),
            bgcolor="white",
            borderpad=4
        )
    
    # Add vertical line at x=0
    fig.add_shape(type="line", line=dict(dash="dash"), x0=0, x1=0, y0=-3, y1=3)
    
    # Add horizontal line at y=0
    fig.add_shape(type="line", line=dict(dash="dash"), y0=0, y1=0, x0=-3, x1=3)
    
    # Update layout, titles, and axis ranges
    fig.update_layout(title=f"Stress Quadrants: {title}", 
                      xaxis_title="zrating", 
                      yaxis_title="zstress",
                      legend_title="Quadrants",
                      height=800)

    # Display the plot
    fig.show()

# %%
plot_quadrants(df=results_pre_covid, title=f"Before COVID-19 ({covid_start_date})")

# %%
plot_quadrants(results_during_covid, title=f"During/After COVID-19 ({covid_start_date})")

# %%
results_pre_covid
# Out:
#                                     company name  company_id  average_rating  \
# 0                         IHG Hotels and Resorts        4232        3.737639
# 1                  FCA Fiat Chrysler Automobiles         149        3.319199
# 2                                     Penn State        2931        4.066023
# 3                                         NetApp        5406        3.595722
# 4                                         Mercer       35818        3.216216
# ...                                          ...         ...             ...
# 5212  NYS Office Information Technology Services      703480        2.671141
# 5213                                       Turn5      341949        2.682927
# 5214                               JAKKS Pacific        6084        3.621053
# 5215                           NorthMarq Capital       16676        3.338710
# 5216                           Anne Fontaine USA      462775        2.933333
#
#        zrating    stress   zstress quadrant
# 0     0.436332  0.003532 -0.729921       Q4
# 1    -0.436247  0.006990 -0.386843       Q3
# 2     1.121115  0.002684 -0.814049       Q4
# 3     0.140391  0.006417 -0.443656       Q4
# 4    -0.650997  0.005019 -0.582338       Q3
# ...        ...       ...       ...      ...
# 5212 -1.787649  0.026846  1.583140       Q2
# 5213 -1.763072  0.012195  0.129603       Q2
# 5214  0.193213  0.021053  1.008392       Q1
# 5215 -0.395560  0.016129  0.519902       Q2
# 5216 -1.240896  0.022222  1.124432       Q2
#
# [5217 rows x 7 columns]

# %%
results_during_covid
# Out:
#                        company name  company_id  average_rating   zrating  \
# 0            IHG Hotels and Resorts        4232        3.934496  0.415672
# 1     FCA Fiat Chrysler Automobiles         149        3.488924 -0.975659
# 2                        Penn State        2931        4.216767  1.297086
# 3                            NetApp        5406        4.128931  1.022811
# 4                            Mercer       35818        3.760222 -0.128510
# ...                             ...         ...             ...       ...
# 5365                         Skyeng     1063171        3.927022  0.392334
# 5366                    @properties      349652        3.960317  0.496303
# 5367                          Turn5      341949        3.456140 -1.078028
# 5368                           KeyW      354608        4.033898  0.726064
# 5369              Anne Fontaine USA      462775        3.638743 -0.507836
#
#         stress   zstress quadrant
# 0     0.002641 -0.828235       Q4
# 1     0.005538 -0.462486       Q3
# 2     0.001853 -0.927808       Q4
# 3     0.003145 -0.764680       Q4
# 4     0.004764 -0.560238       Q3
# ...        ...       ...      ...
# 5365  0.003945 -0.663653       Q4
# 5366  0.007937 -0.159634       Q4
# 5367  0.017544  1.053442       Q2
# 5368  0.016949  0.978351       Q1
# 5369  0.047120  4.787939       Q2
#
# [5370 rows x 7 columns]

# %%
def calculate_association(df):
    R = np.sqrt(np.power(df["zrating"], 2) + np.power(df["zstress"], 2))

    alpha = np.arccos(np.abs(df["zrating"]) / R)
    beta = np.arccos(np.abs(df["zstress"]) / R)
    gamma = np.maximum((alpha - np.pi / 4), (beta - np.pi / 4))

    return pd.Series(R / (gamma + np.pi))

# %%
results_pre_covid["association"] = calculate_association(results_pre_covid)
results_during_covid["assocation"] = calculate_association(results_during_covid)

# %% [markdown]
# ### 4.2. Computing Stress Scores Over the Years

# %%
# Compute the scores for the whole data (without cutoff point)
avg_rating = compute_average_rating_per_company(reviews)
stress = compute_stress_score_per_company(reviews)

results = pd.merge(left=avg_rating, right=stress, on="company_id")
results = pd.merge(left=companies, right=results, left_on="_id", right_on="company_id")

results["association"] = calculate_association(results)

del results["_id"]

# %%
plot_quadrants(results, "All Years")

# %%
results.head()
# Out:
#                     company name  company_id  average_rating   zrating  \
# 0         IHG Hotels and Resorts        4232        3.833806  0.454736
# 1  FCA Fiat Chrysler Automobiles         149        3.382111 -0.796629
# 2                     Penn State        2931        4.146942  1.322239
# 3                         NetApp        5406        3.775850  0.294175
# 4                         Mercer       35818        3.484439 -0.513142
#
#      stress   zstress  association quadrant
# 0  0.003097 -0.782521     0.266148       Q4
# 1  0.006452 -0.208491     0.224314       Q3
# 2  0.002238 -0.929515     0.487669       Q4
# 3  0.005312 -0.403551     0.151464       Q4
# 4  0.004893 -0.475122     0.219911       Q3

# %%
def calculate_weight(df):
    temp = df.groupby(by="company_id").size()
    temp = temp.reset_index(name="count")

    temp["weight"] = temp["count"] / df.shape[0]

    return temp

# %%
grouped = reviews.groupby(reviews["reviewDateTime"].dt.year)

# %%
stress_over_years = {}

for year, group in grouped:
    
    # Compute the scores for the whole data (without cutoff point)
    avg_rating = compute_average_rating_per_company(group)
    stress = compute_stress_score_per_company(group)

    results = pd.merge(left=avg_rating, right=stress, on="company_id")
    results = pd.merge(left=companies, right=results, left_on="_id", right_on="company_id")

    results["association"] = calculate_association(results)

    weights = calculate_weight(group)
    results = pd.merge(left=results, right=weights, on="company_id")

    del results["_id"]
    del results["count"]

    stress_over_years[year] = np.sum(results["association"] * results["weight"])

# %%
stress_over_years
# Out:
# {2008: 0.09324091240870061,
#  2009: 0.07116437805398336,
#  2010: 0.06416544064484744,
#  2011: 0.0962872832321128,
#  2012: 0.11143981724722324,
#  2013: 0.10595639243912847,
#  2014: 0.13365759239297104,
#  2015: 0.11867266216490756,
#  2016: 0.11559177132537822,
#  2017: 0.13039039906966987,
#  2018: 0.12516665354421314,
#  2019: 0.12799110235879727,
#  2020: 0.1394409159276057,
#  2021: 0.19642980020771347,
#  2022: 0.1958061097487982,
#  2023: 0.14480755369180437}

# %%
years = list(stress_over_years.keys())
stress_values = list(stress_over_years.values())

# Create a trace for the stress values
trace = go.Scatter(
    x=years,
    y=stress_values,
    mode='lines+markers',
    name='Stress',
    marker=dict(
        size=8,
        color='blue'
    ),
    line=dict(
        width=2
    )
)

layout = go.Layout(
    title='Stress Over the Years',
    xaxis=dict(title='Year'),
    yaxis=dict(title='Stress'),
    hovermode='closest'
)

fig = go.Figure(data=[trace], layout=layout)

# Show the plot (you can also save it to an HTML file)
fig.show()
